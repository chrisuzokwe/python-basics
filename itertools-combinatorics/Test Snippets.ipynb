# %%
## np.arange
import numpy as np
import itertools
import matplotlib.pyplot as plt
x0 = 13.02222222222212314
x1 = 69.3412414
y0 = 13.02222222222212314
y1 = 69.3412414


xcount = round((x1-x0)/0.5)
ycount = round((y1-y0)/0.5)
print(type(xcount))
px = np.linspace(x0, x1, 15)
py = np.linspace(y0, y1, 15)

poly1 = [(x0, y) for y in py]
poly2 = [(x1, y) for y in py]
poly3 = [(y0, x) for x in px]
poly4 = [(y1, x) for x in px]

print(px)
print('\n\n\n\n\n')
print(poly1, poly2, poly3, poly4)

newpoly = np.concatenate((poly1, poly2, poly3, poly4))
newpoly = np.array(list(np.hstack(newpoly)))
newpoly = (np.transpose(newpoly.reshape((np.shape(newpoly)[0],1)))).tolist()

length = len(newpoly)

a = newpoly.pop()
print(a , "here")

    
print(np.shape(newpoly))
print(newpoly)





poly = itertools.product(px, py)
poly = list(poly)
print('\n\n\n\n\n')
poly = np.array(list(np.hstack(poly)))
poly = (np.transpose(poly.reshape((np.shape(poly)[0],1)))).tolist()
print(np.shape(poly))
print(poly)
# Out:
# <class 'int'>
# [13.02222222 17.04500931 21.06779639 25.09058347 29.11337056 33.13615764
#  37.15894473 41.18173181 45.2045189  49.22730598 53.25009306 57.27288015
#  61.29566723 65.31845432 69.3412414 ]
#
#
#
#
#
#
# ...

# %%
## itertools combiniatorics
import itertools

test = [(1,1),(2,2),(3,3)]
x = itertools.product(test, repeat=2)
for item in x:
    print(item)
# Out:
# ((1, 1), (1, 1))
# ((1, 1), (2, 2))
# ((1, 1), (3, 3))
# ((2, 2), (1, 1))
# ((2, 2), (2, 2))
# ((2, 2), (3, 3))
# ((3, 3), (1, 1))
# ((3, 3), (2, 2))
# ((3, 3), (3, 3))

# %%
## np.shape

x = [[1,2,3,4,5], [5,4,3,2,1]]
y = [[1,2,3,4,5], [5,4,3,2,1]]
x = np.array(x)
print(x/x.max())
# Out:
# [[0.2 0.4 0.6 0.8 1. ]
#  [1.  0.8 0.6 0.4 0.2]]
